# %%
# %pylab inline
from sklearn.neural_network import MLPRegressor
import bilby
import redback
import pandas as pd
from bilby.core.prior import Constraint, PriorDict, Uniform
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
import matplotlib.pyplot as plt
from redback.transient_models.afterglow_models import tophat
from sklearn import preprocessing as pre
import scipy.constants as const
from sklearn.model_selection import GridSearchCV
import random
import pickle
from scipy import interpolate
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
def line(x, m, c, **kwargs):
    return m*x+c

prior = bilby.core.prior.PriorDict()
prior['m'] = bilby.core.prior.Uniform(3, 8, 'm')
prior['c'] = bilby.core.prior.Uniform(-2, 2, 'c')

# %%
xs = np.linspace(1, 20, 50)
models = 100
ys = np.zeros((models, len(xs)))
samples = pd.DataFrame(prior.sample(models))

# %%
for ii in range(models):
    ys[ii] = line(xs, **samples.iloc[ii].to_dict())
    plt.plot(xs, ys[ii], color='red', alpha=0.05)

# %%
X_train = samples.values
y_train = ys
regr = MLPRegressor(random_state=1, max_iter=5000).fit(X_train, y_train)

# %%
y_pred = regr.predict(np.array([4, -1]).reshape(1, -1))
print(y_pred.shape)
# Out:
# (1, 50)

# %%
y_true = line(xs, 4, -1)

# %%
plt.plot(xs, y_true, color='red')
plt.plot(xs, y_pred[0,:], color='blue')

# %%
def afterglow(time, redshift,  thv, loge0 , thc, logn0, p, logepse, logepsb, ksin, g0, frequency):
    ag_fluxd = redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, av=0.5,
        base_model='tophat', output_format='flux_density', redshift=redshift,  thv=thv, loge0=loge0 , thc=thc, logn0=logn0, p=p, logepse=logepse,
        logepsb=logepsb, ksin=ksin, g0=g0, frequency= frequency)
    return ag_fluxd

# %%
def afterglow_constraints(parameters):
    constrained_params= parameters.copy()
    
    time=np.linspace(0.1,300,300) #make sure time arrays match
    maxflux=[]
    peaktime=[]
    minflux=[]
    for i in range(len(parameters['thv'])):
        flux= redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, redshift=0.01, av=0.5,
            base_model='tophat',  thv= parameters['thv'][i], loge0=parameters['loge0'][i] , thc=parameters['thc'][i], logn0=parameters['logn0'][i], 
            p=2.3, logepse=-1.25, logepsb=-2.5, ksin=1.0, g0=1000,
            output_format='flux_density', frequency=1146839759677006.2)
        maxflux.append(max(flux))
        peaktime.append(time[np.argmax(flux)])
        fluxday1= np.interp(1,time,flux)
        minflux.append(fluxday1)
        
    #peak flux must be at times < 200 days
    constrained_params['peak_time']= 200 - np.array(peaktime)
    #peak flux must be greater than 10e-12
    constrained_params['max_flux']= np.array(maxflux) - (10e-12)
    #thv must be greater than thc
    constrained_params['valid_jet']= parameters['thv'] - parameters['thc']
    #filter on axis results (comment out if needed)
    #constrained_params['onaxis']= 0.05 - parameters['thv']
    #filter lower flux afterglows out for ON AXIS case (comment out if needed)
    #constrained_params['min_flux']= np.array(minflux) - 10e-7
    #filter off axis results (comment out if needed)
    constrained_params['offaxis']= parameters['thv'] - 0.06
    return constrained_params

# %%
priors = PriorDict(conversion_function=afterglow_constraints)
priors['max_flux']= Constraint(minimum=0, maximum=20)
priors['peak_time']= Constraint(minimum=0, maximum=250)
#priors['onaxis']= Constraint(minimum=0, maximum=0.05)
#priors['min_flux']=Constraint(minimum=0, maximum=10)
priors['offaxis']= Constraint(minimum=0.06, maximum=(np.pi)/2)
priors.update(redback.priors.get_priors(model='tophat'))
priors['p']=  2.3
priors['loge0']= Uniform(minimum=46, maximum=53, name='loge0', latex_label='$\\log_{10}E_{0}$', unit=None, boundary=None)
priors['redshift']= 0.01
priors['logepse']= -1.25
priors['logepsb']= -2.5
priors['ksin']= 1.0
priors['g0']= 1000
priors['frequency']= Uniform(minimum=5e9, maximum=2e17, name='frequency', latex_label='$frequency$', unit=None, boundary=None)

num=10000
samples=priors.sample(num)
afterglow_data=pd.DataFrame.from_dict(samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 priors = PriorDict(conversion_function=afterglow_constraints)
#       2 priors['max_flux']= Constraint(minimum=0, maximum=20)
#       3 priors['peak_time']= Constraint(minimum=0, maximum=250)
#
# NameError: name 'afterglow_constraints' is not defined

# %%
time = np.linspace(0.1, 300, 600) #xs
yvals = np.zeros((num, len(time)))  #ys

# %%
ax= plt.subplot()

for i in range(num):
    yvals[i]= afterglow(time, **afterglow_data.iloc[i])
    ax.loglog(time, yvals[i], color='c', alpha=0.05)
plt.show()

# %%
X = afterglow_data.values
Y = yvals
regr = MLPRegressor(random_state=7, max_iter=7000, hidden_layer_sizes=(200,),activation='logistic',solver='sgd', learning_rate='adaptive').fit(X, Y)

# %%
params=np.array([0.01, 0.5, 50.0 , 0.02, 1, 2.13,-1.25, -2.5, 1, 1000, 4e14])
prediction = regr.predict(params.reshape(1,-1))
prediction.shape
# Out:
# (1, 600)

# %%
test_params= dict(redshift=0.01,  thv= 0.5, loge0=50.0 , thc= 0.02, logn0=1, p=2.13, logepse=-1.25, logepsb=-2.5, ksin=1, g0=1000,
     frequency= 4e14)
true_value= afterglow(time, **test_params)
ax1=plt.subplot()
ax1.loglog(time, true_value, color='red')
ax1.loglog(time, prediction[0,:], color='blue')#, ls='None', marker='x')
plt.show()

# %%
def tophat_func(time,  thv, loge0 , thc, logn0, p, logepse, logepsb, g0,frequency):
    flux= tophat(time=time, output_format='flux_density', redshift=0.01,  thv=thv, loge0=loge0 , thc=thc, logn0=logn0, p=p, logepse=logepse,
        logepsb=logepsb, ksin=1, g0=g0, frequency= frequency)
    return flux

# %%
general_priors= redback.priors.get_priors(model='tophat')
#general_priors['frequency']= Uniform(minimum=1e13, maximum=2e15, name='frequency', latex_label='$frequency$', unit=None, boundary=None)
frequency=[]
for f in range(9,18):
    rand_samples=(random.sample(range(10**f,10**(f+1)),10000))
    frequency.extend(rand_samples)

random.shuffle(frequency)
num=90000
tnum=100
samples=general_priors.sample(num)
samples['frequency']=frequency
tophat_data=pd.DataFrame.from_dict(samples)
unprocessed= pd.DataFrame.from_dict(samples)
tophat_data.drop('redshift', axis=1,inplace=True)
tophat_data.drop('ksin', axis=1,inplace=True)
unprocessed.drop('redshift', axis=1,inplace=True)
unprocessed.drop('ksin', axis=1,inplace=True)

tophat_data['thv']=np.log10(tophat_data['thv'])
tophat_data['thc']=np.log10(tophat_data['thc'])
tophat_data['g0']=np.log10(tophat_data['g0'])
tophat_data['frequency']=np.log10(tophat_data['frequency'])

min(unprocessed['frequency'])
# Out:
# 1001308747

# %%
training = tophat_data.iloc[:(num-tnum)]
testing = tophat_data.iloc[(num-tnum):]

# %%
testing
# Out:
#             thv      loge0       thc     logn0         p   logepse   logepsb  \
# 89900 -0.404274  52.177119 -1.609325 -1.330084  2.660084 -1.592164 -1.246722
# 89901  0.026136  47.561988 -1.290502  0.854014  2.082030 -1.683829 -0.386513
# 89902  0.143897  47.183270 -1.857715 -2.011680  2.307108 -1.669488 -3.156843
# 89903  0.113055  50.314121 -1.101859  1.767306  2.324056 -0.532603 -2.733861
# 89904 -0.029312  51.156009 -1.183820  1.719215  2.958216 -4.913097 -0.216289
# ...         ...        ...       ...       ...       ...       ...       ...
# 89995 -0.002243  51.675212 -1.229062 -2.211468  2.632966 -3.048028 -2.927079
# 89996 -0.222971  45.646223 -1.160634  1.508721  2.077594 -4.211058 -0.434856
# 89997 -0.378855  49.869892 -1.155887  1.552861  2.312081 -1.641574 -3.249588
# 89998 -0.478790  52.580595 -1.086198 -3.039724  2.831036 -4.973675 -3.081222
# 89999  0.040711  53.078349 -1.082256 -1.898550  2.456387 -4.326760 -0.126323
#
#              g0  frequency
# 89900  3.193988  17.981012
# 89901  3.298221  14.579499
# 89902  3.261509  13.995137
# 89903  2.101186  15.725627
# 89904  3.272416  13.546450
# ...         ...        ...
# 89995  3.115049   9.960818
# 89996  2.767303   9.867585
# 89997  2.579465  11.646978
# 89998  2.881726  14.993439
# 89999  3.147832  15.681398
#
# [100 rows x 9 columns]

# %%
time = np.linspace(0.1, 300, 150) #xs
ys = np.zeros((num-tnum, len(time)))  #ys

ax= plt.subplot()

for i in range(num-tnum):
    ys[i]= tophat_func(time, **unprocessed.iloc[i])
    ax.loglog(time, ys[i], color='c', alpha=0.05)
plt.show()

# %%
scalerx = pre.StandardScaler()
scalery = pre.StandardScaler()
Y_train = scalery.fit_transform(np.log10(ys))
X_train = scalerx.fit_transform(training.values)
X_test= scalerx.transform(testing.values)

#params=np.array([0.5, 50.0 , 0.02, 1, 2.13,-1.25,-2.5, 1000])
#prediction = regr.predict(params.reshape(1,-1))

# %%
regressor = MLPRegressor(random_state=7, max_iter=1000, hidden_layer_sizes=(800,800,800), activation='relu',solver='adam',learning_rate='adaptive',
                   learning_rate_init=1e-4, batch_size=64).fit(X_train, Y_train)

# %%
prediction = regressor.predict(X_test)
prediction = 10**(scalery.inverse_transform(prediction))
prediction.shape
# Out:
# (100, 150)

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(9,9), sharex=True, sharey=True)
time = np.linspace(0.1, 300, 150) #xs
#test_params= dict(thv= 0.5, loge0=50.0 , thc= 0.02, logn0=1, p=2.13, logepse=-1.25, logepsb=-2.5, g0=1000)

for i in range(15): 
    true_value= tophat_func(time, **unprocessed.iloc[i+(num-tnum)])
    ax[0,0].loglog(time, true_value, color='red', alpha=0.2)
    ax[0,0].loglog(time, prediction[i], color='blue', alpha=0.2)
for i in range(15,30): 
    true_value= tophat_func(time, **unprocessed.iloc[i+(num-tnum)])
    ax[0,1].loglog(time, true_value, color='red', alpha=0.2)
    ax[0,1].loglog(time, prediction[i], color='blue', alpha=0.2)
for i in range(30,45): 
    true_value= tophat_func(time, **unprocessed.iloc[i+(num-tnum)])
    ax[1,0].loglog(time, true_value, color='red', alpha=0.2)
    ax[1,0].loglog(time, prediction[i], color='blue', alpha=0.2)
for i in range(45,60): 
    true_value= tophat_func(time, **unprocessed.iloc[i+(num-tnum)])
    ax[1,1].loglog(time, true_value, color='red', alpha=0.2)
    ax[1,1].loglog(time, prediction[i], color='blue', alpha=0.2)
for i in range(60,75): 
    true_value= tophat_func(time, **unprocessed.iloc[i+(num-tnum)])
    ax[0,2].loglog(time, true_value, color='red', alpha=0.2)
    ax[0,2].loglog(time, prediction[i], color='blue', alpha=0.2)
for i in range(75,90): 
    true_value= tophat_func(time, **unprocessed.iloc[i+(num-tnum)])
    ax[1,2].loglog(time, true_value, color='red', alpha=0.2)
    ax[1,2].loglog(time, prediction[i], color='blue', alpha=0.2)

#true_value= tophat_func(time, **unprocessed.iloc[2+(num-tnum)])
#ax[0,0].loglog(time, true_value, color='red', alpha=0.5)
plt.savefig("emulation_final.png", dpi='figure')
plt.show()

# %%
with open("tophat.pkl", "wb") as f:
    pickle.dump(regr, f)

# %%
with open("improved_tophat.pkl", "wb") as file:
    pickle.dump(regressor, file)

# %%
with open("scalery.pkl", "wb") as sy:
    pickle.dump(scalery, sy)
with open("scalerx.pkl", "wb") as sx:
    pickle.dump(scalerx, sx)

# %%
with open("new_scalery.pkl", "wb") as sy:
    pickle.dump(scalery, sy)
with open("new_scalerx.pkl", "wb") as sx:
    pickle.dump(scalerx, sx)

# %%
params={}
params['thv']= np.log10(0.5)
params['loge0'] = 49.5
params['thc'] = np.log10(0.6)
params['logn0'] = 0.5 
params['p'] = 2.3
params['logepse'] = -1.25
params['logepsb'] = -2.5
params['g0'] = np.log10(1000)
params['frequency']=np.log10(2e14)
test=np.fromiter(params.values(),dtype=float).reshape(1,-1)

# %%
time=np.linspace(0.1,300,150)
with open("improved_tophat.pkl", "rb") as f:
    model = pickle.load(f)
with open("new_scalery.pkl", "rb") as sy:
    scalery = pickle.load(sy)
with open("new_scalerx.pkl", "rb") as sx:
    scalerx = pickle.load(sx) 

xtests= scalerx.transform(testing.values)
prediction= model.predict(xtests)
prediction = 10**(scalery.inverse_transform(prediction))

afterglow = interpolate.interp1d(time, prediction, kind='linear')
new_time= np.linspace(0.1,50,50)
fluxd= afterglow(new_time)

ax=plt.subplot()
for i in range(15,40):
    true_value= tophat_func(new_time, **unprocessed.iloc[i+(num-tnum)])
    ax.loglog(new_time, true_value, color='red', alpha=0.2)
    ax.loglog(new_time, fluxd[i], color='blue', alpha=0.2)
plt.show()

# %%
scalery
# Out:
# StandardScaler()

# %%
prediction.shape
# Out:
# (100, 150)

# %%
xtests.shape
# Out:
# (100, 9)

# %%
unprocessed.iloc[2+(num-tnum)]
# Out:
# thv          1.122384e+00
# loge0        5.159928e+01
# thc          1.529868e-02
# logn0       -1.734760e+00
# p            2.967152e+00
# logepse     -3.121768e-01
# logepsb     -6.179132e-01
# g0           5.168700e+02
# frequency    6.516236e+14
# Name: 79902, dtype: float64

# %%
unprocessed.iloc[11+(num-tnum)]
# Out:
# thv          6.543900e-02
# loge0        4.983819e+01
# thc          2.080898e-02
# logn0       -3.140924e+00
# p            2.251693e+00
# logepse     -3.730114e+00
# logepsb     -3.953608e+00
# g0           2.132696e+02
# frequency    3.087617e+17
# Name: 79911, dtype: float64

# %%
unprocessed['frequency'].iloc[num-tnum:].values
# Out:
# array([1.00656140e+14, 1.06020086e+15, 1.29688986e+15, 1.12992999e+15,
#        4.47437220e+14, 1.93297609e+15, 7.56629244e+14, 9.70446701e+14,
#        1.17409372e+15, 1.41467503e+14, 4.49154818e+13, 7.81176125e+14,
#        1.66962403e+15, 1.04042828e+15, 2.82502902e+14, 1.59135245e+15,
#        1.80573842e+15, 1.26905363e+15, 1.26559804e+15, 1.52777522e+15,
#        1.19898263e+15, 6.07214871e+14, 6.64438092e+14, 1.87507081e+15,
#        2.52054190e+13, 3.56368518e+14, 1.29395306e+15, 4.69968628e+14,
#        1.28224333e+15, 6.25654261e+14, 1.03705093e+14, 9.67024739e+14,
#        1.24829321e+15, 1.94731382e+14, 1.24752724e+15, 7.51019582e+14,
#        2.12234999e+14, 1.98934120e+15, 1.62828601e+15, 1.69866155e+14,
#        4.20091907e+13, 1.41625790e+15, 1.71859143e+15, 1.50969322e+15,
#        1.56926946e+15, 1.16343556e+15, 4.51808285e+14, 1.97380320e+14,
#        3.56269372e+14, 1.60267180e+15, 9.03281048e+14, 1.46055184e+15,
#        1.54683553e+15, 1.28757302e+15, 1.33752192e+14, 4.20890107e+14,
#        4.04473695e+14, 6.90350798e+14, 1.39691804e+15, 3.66656945e+14,
#        2.96770793e+14, 1.11283225e+15, 1.90927325e+15, 1.58574409e+15,
#        7.53829426e+14, 8.96776699e+14, 8.86042984e+14, 1.46074980e+15,
#        1.62015292e+15, 1.99144013e+13, 1.56784013e+15, 1.26557471e+15,
#        1.97554941e+15, 1.13008587e+15, 9.10624260e+14, 1.48696141e+15,
#        5.17846347e+14, 1.07804632e+14, 5.51102030e+14, 4.50777317e+14,
#        8.87293223e+14, 4.15052922e+14, 7.61399376e+14, 6.82997050e+14,
#        1.60723686e+15, 8.97685912e+14, 1.70860629e+15, 6.20361783e+14,
#        1.57738858e+15, 7.55573611e+13, 7.93071508e+14, 1.00485695e+15,
#        2.62937546e+14, 1.04070194e+15, 8.40727324e+14, 1.58821905e+15,
#        9.48589147e+14, 6.42014237e+13, 8.84024540e+14, 7.07155592e+14])

# %%
print(regr.n_iter_, regr.best_loss_)
# Out:
# 73 0.005612029467075825

# %%
print(regr.n_iter_, regr.best_loss_)
# Out:
# 38 0.0013669637969929973

# %%
print(regr.n_iter_, regr.best_loss_, regr.t_)
# Out:
# 10 0.0014232664780402901 999000

# %%
param_grid={}
param_grid['hidden_layer_sizes']=[(500,500,500), (800,800,800)]
param_grid['activation']=['tanh','relu', 'logistic']
param_grid['solver']=['adam','sgd']
param_grid['batch_size']=[64, 128]
param_grid['learning_rate_init']=[0.001, 1e-4]

# %%
mlp = MLPRegressor(random_state=7, max_iter=1000)
tuner = GridSearchCV(mlp, param_grid, n_jobs=-1, cv=3, verbose=3, pre_dispatch=3)
tuner.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.996 total time= 1.5min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 1.8min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.3min
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.2min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.2min
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.993 total time= 4.0min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 1.4min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.994 total time= 3.7min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.993 total time= 3.9min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 2.8min
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 3.0min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 3.7min
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.9min
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.996 total time= 3.2min
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 4.1min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 2.3min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.996 total time= 5.1min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 4.1min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 1.3min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.997 total time= 1.7min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.995 total time= 3.4min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.998 total time= 3.0min
# [CV 3/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.994 total time= 9.5min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 1.2min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.996 total time= 1.2min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.3min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.2min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.990 total time= 4.7min
# [CV 1/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.993 total time=10.4min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 1.5min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.991 total time= 4.3min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 3.1min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 3.0min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.7min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 3.0min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 3.3min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.7min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 3.0min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 3.2min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.6min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 2.6min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 3.6min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 1.6min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.998 total time= 1.1min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.0min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.4min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.5min
# [CV 3/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.992 total time=12.3min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.993 total time= 1.8min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 1.1min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 3.6min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.992 total time= 1.9min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.998 total time= 2.4min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.991 total time=12.2min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.992 total time= 1.8min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.998 total time= 2.2min
# [CV 2/3] END activation=tanh, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.994 total time=10.3min
# [CV 2/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.990 total time= 4.3min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 2.9min
# [CV 1/3] END activation=tanh, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.990 total time=12.1min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 1.2min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 3.5min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.999 total time= 2.5min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.996 total time= 1.1min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.993 total time= 5.3min
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 1.2min
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.997 total time= 1.2min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.999 total time= 2.7min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 1.1min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 2.1min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.3min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 2.4min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.0min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 3.6min
# [CV 2/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.993 total time= 5.1min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.3min
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 2.2min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.989 total time= 2.1min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 2.6min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.999 total time= 3.1min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.999 total time=  51.3s
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.990 total time= 2.0min
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 2.6min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.989 total time= 2.1min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 3.1min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.998 total time= 1.3min
# [CV 1/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.998 total time= 2.4min
# [CV 3/3] END activation=relu, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.994 total time= 5.4min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 2.6min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.991 total time= 5.1min
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.0min
# [CV 1/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 2.4min
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.991 total time= 5.1min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.997 total time= 1.0min
# [CV 3/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 2.0min
# [CV 2/3] END activation=relu, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=0.991 total time= 5.0min
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.992 total time= 3.4min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 3.3min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.996 total time= 3.6min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.978 total time= 6.0min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.986 total time= 6.3min
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.980 total time= 6.1min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.986 total time= 5.9min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=-0.001 total time=  48.5s
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.988 total time= 6.9min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.988 total time= 7.2min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=0.000 total time=  55.4s
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=-0.001 total time= 1.3min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 8.2min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.999 total time= 8.7min
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.780 total time= 3.9min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=-0.000 total time= 1.8min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.990 total time=17.1min
# [CV 3/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 4.1min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.978 total time=15.1min
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=-0.006 total time= 1.9min
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 3.6min
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.982 total time= 6.8min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.989 total time=15.1min
# [CV 3/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=-0.001 total time= 3.4min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 3.2min
# [CV 3/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.984 total time= 7.1min
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 7.3min
# [CV 1/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.984 total time=16.0min
# [CV 2/3] END activation=logistic, batch_size=64, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.989 total time=14.4min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.001, solver=sgd;, score=0.983 total time= 6.0min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.988 total time= 6.5min
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=-0.001 total time=  36.6s
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.987 total time= 7.6min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=-0.001 total time=  26.6s
# [CV 3/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=adam;, score=0.988 total time= 6.8min
# [CV 3/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(500, 500, 500), learning_rate_init=0.0001, solver=sgd;, score=-0.000 total time= 1.1min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.998 total time= 7.7min
# [CV 3/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 7.9min
# [CV 3/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=-0.008 total time= 1.3min
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=-0.000 total time= 1.7min
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.988 total time=17.1min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=-0.001 total time= 1.1min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.987 total time=21.8min
# [CV 3/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=sgd;, score=-0.003 total time= 1.1min
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=adam;, score=0.997 total time= 7.6min
# [CV 1/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.001, solver=sgd;, score=0.984 total time=18.4min
# [CV 2/3] END activation=logistic, batch_size=128, hidden_layer_sizes=(800, 800, 800), learning_rate_init=0.0001, solver=adam;, score=0.990 total time=14.5min
# GridSearchCV(cv=3, estimator=MLPRegressor(max_iter=1000, random_state=7),
#              n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu', 'logistic'],
#                          'batch_size': [64, 128],
#                          'hidden_layer_sizes': [(500, 500, 500),
#                                                 (800, 800, 800)],
#                          'learning_rate_init': [0.001, 0.0001],
#                          'solver': ['adam', 'sgd']},
#              pre_dispatch=3, verbose=3)

# %%
tuner.best_score_
# Out:
# 0.9987270022686235

# %%
tuner.best_params_
# Out:
# {'activation': 'relu',
#  'batch_size': 64,
#  'hidden_layer_sizes': (800, 800, 800),
#  'learning_rate_init': 0.0001,
#  'solver': 'adam'}

# %%
def power(frequency, g0, logepsb, logn0):
    me= const.m_e
    mp= const.m_p
    c= const.c
    sigma = const.sigma
    q=const.e
    n0= 10**(logn0)
    epsb= 10**(logepsb)
    constant = (me*(c**3)*sigma*((32*np.pi*mp)**0.5))/(3*q)

    pow= constant*(g0**2)*((epsb*n0)**0.5)*frequency*10e7 #power in ergs
    return pow

# %%
pprior = bilby.core.prior.PriorDict()
pprior['g0'] = bilby.core.prior.Uniform(100, 2000, 'g0')
pprior['logepsb'] = bilby.core.prior.Uniform(-5, 0, 'c')
pprior['logn0']=bilby.core.prior.Uniform(-5,2,'logn0')
pprior
# Out:
# {'g0': Uniform(minimum=100, maximum=2000, name='g0', latex_label='g0', unit=None, boundary=None),
#  'logepsb': Uniform(minimum=-5, maximum=0, name='c', latex_label='c', unit=None, boundary=None),
#  'logn0': Uniform(minimum=-5, maximum=2, name='logn0', latex_label='logn0', unit=None, boundary=None)}

# %%
N= 5000
samples=pprior.sample(N)
power_data=pd.DataFrame.from_dict(samples)
power_data
# Out:
#                g0   logepsb     logn0
# 0      185.380307 -2.711978  0.601665
# 1     1423.031101 -4.650265  1.992532
# 2      394.884171 -0.541732 -1.991962
# 3     1221.158402 -4.845642  1.404221
# 4      415.062706 -3.860507 -4.259996
# ...           ...       ...       ...
# 4995   944.116862 -2.469384 -2.699051
# 4996  1360.925225 -1.993366  0.738621
# 4997   959.389273 -3.519324  1.084934
# 4998   797.601144 -0.752727 -0.088104
# 4999   972.597565 -1.504777 -3.382704
#
# [5000 rows x 3 columns]

# %%
frequency = np.linspace(2e16, 2e17, 500) #xs
y = np.zeros((4900, len(frequency)))  #ys  

ax= plt.subplot()
for i in range(4900):
    y[i]= power(frequency, **power_data.iloc[i])
    ax.loglog(frequency, y[i], color='c', alpha=0.05)
plt.show()

# %%
y_train= y
scaler = pre.StandardScaler()
x_train=power_data.iloc[:4900].values
scaler.fit(x_train)  
x_train = scaler.transform(x_train) 

x_test=power_data.iloc[4900:].values
x_test = scaler.transform(x_test)

regress = MLPRegressor(random_state=7, max_iter=2000, hidden_layer_sizes=(100,), activation='tanh',solver='sgd',learning_rate='adaptive', 
                       learning_rate_init=1e-5, batch_size= 16).fit(x_train, y_train)

# %%
prediction = regress.predict(x_test)
#print(prediction)
#test_params= dict(thv= 0.5, loge0=50.0 , thc= 0.02, logn0=1, p=2.13, logepse=-1.25, logepsb=-2.5, g0=1000)
ax2=plt.subplot()
for i in range(100): 
    true_value= power(frequency, *x_test[i])
    ax2.loglog(frequency, true_value, color='red', alpha=0.1)
    ax2.loglog(frequency, prediction[i], color='blue', alpha=0.1)# ls='None', marker='x')
    #print(regr.score(testing.values[i].reshape(1,-1),true_value.reshape(1,-1)))
#plt.ylim(10e22,10e25)
plt.show()

# %%
from redback.simulate_transients import SimulateGenericTransient
times= np.linspace(0.1,40,30)
num_points=500
noise=0.05

bands = ['F160W', 'F110W','lssty', 'lsstz','lssti', 'lsstr','lsstg','lsstu', 'uvot::uvw1']
frequencies=[5e9, 2e17]
bandfreqs = (redback.utils.bands_to_frequency(bands))
print(bandfreqs)
frequencies.extend(bandfreqs)
frequencies.sort()
frequencies

model_kwargs = {'output_format':'flux_density', 'frequency':frequencies}

params={}
params['av'] = 0.5
params['loge0'] = 49.5
params['logn0'] = 0.5 
params['p'] = 2.3
params['logepse'] = -1.25
params['logepsb'] = -2.5
params['g0'] = 1000
params['thv']= 0.5
params['thc'] = 0.6
params['base_model']='tophat_from_emulator'
    
tophatag =  SimulateGenericTransient(model='extinction_with_afterglow_base_model', parameters=params,
                                            times=times, data_points=num_points, model_kwargs=model_kwargs, 
                                            multiwavelength_transient=True, noise_term=noise)
tophatag.data
# Out:
# [1.952e+14 2.601e+14 3.083e+14 3.454e+14 3.983e+14 4.825e+14 6.273e+14
#  8.152e+14 1.141e+15]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 28
#      25 params['thc'] = 0.6
#      26 params['base_model']='tophat_from_emulator'
# ---> 28 tophatag =  SimulateGenericTransient(model='extinction_with_afterglow_base_model', parameters=params,
#      29                                             times=times, data_points=num_points, model_kwargs=model_kwargs,
#      30                                             multiwavelength_transient=True, noise_term=noise)
#      31 tophatag.data
#
# File ~/redback/redback/simulate_transients.py:71, in SimulateGenericTransient.__init__(self, model, parameters, times, model_kwargs, data_points, seed, multiwavelength_transient, noise_term)
#      68     injection_kwargs['frequency'] = self.subset_frequency
#      69     injection_kwargs['output_format'] = 'flux_density'
# ---> 71 true_output = self.model(self.subset_times, **injection_kwargs)
#      72 data = pd.DataFrame()
#      73 data['time'] = self.subset_times
#
# File ~/redback/redback/transient_models/extinction_models.py:231, in extinction_with_afterglow_base_model(time, av, **kwargs)
#     219 @citation_wrapper('https://ui.adsabs.harvard.edu/abs/2021arXiv210601556S/abstract')
#     220 def extinction_with_afterglow_base_model(time, av, **kwargs):
#     221     """
#     222     Extinction with models implemented in afterglow_models
#     223
#    (...)
#     229         Note that only sed varient models can take magnitude as an output
#     230     """
# --> 231     output = _evaluate_extinction_model(time=time, av=av, model_type='afterglow', **kwargs)
#     232     return output
#
# File ~/redback/redback/transient_models/extinction_models.py:115, in _evaluate_extinction_model(time, av, model_type, **kwargs)
#     113 temp_kwargs['output_format'] = 'flux_density'
#     114 function = _get_correct_function(base_model=base_model, model_type=model_type)
# --> 115 flux_density = function(time, **temp_kwargs)
#     116 r_v = kwargs.get('r_v', 3.1)
#     117 flux_density = _perform_extinction(flux_density=flux_density, angstroms=angstroms, av=av, r_v=r_v)
#
# File ~/redback/redback/transient_models/afterglow_models.py:478, in tophat_from_emulator(time, thv, loge0, thc, logn0, p, logepse, logepsb, g0, **kwargs)
#     476 """
#     477
# --> 478 import os
#     479 dirname = os.path.dirname(__file__)
#     480 print(dirname)
#
# ModuleNotFoundError: No module named 'redback_surrogates'
