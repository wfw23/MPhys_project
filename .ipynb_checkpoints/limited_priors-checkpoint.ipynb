# %%
import redback
import numpy as np
import pandas as pd
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
import matplotlib.pyplot as plt
import corner
from bilby.core.prior import Constraint, PriorDict, Uniform, Sine

# %%
bands = ['lsstg', 'lsstr', 'lssti','lsstz','lssty', 'lsstu', 'uvot::uvw1']
frequencies=[5e9, 2e17]
bandfreqs = (redback.utils.bands_to_frequency(bands))
frequencies.extend(bandfreqs)
frequencies.sort()
frequencies
# Out:
# [5000000000.0,
#  308300000000000.0,
#  345400000000000.0,
#  398300000000000.0,
#  482500000000000.0,
#  627300000000000.0,
#  815200000000000.0,
#  1141000000000000.0,
#  2e+17]

# %%
that_priors = redback.priors.get_priors(model='tophat_redback')
#that_priors = redback.priors.get_priors(model='tophat')
that_priors
# Out:
# {'redshift': Uniform(minimum=0.01, maximum=3, name='redshift', latex_label='$z$', unit=None, boundary=None),
#  'thv': Sine(minimum=0, maximum=1.5707963267948966, name='thv', latex_label='$\\theta_{\\mathrm{observer}}~(\\mathrm{rad})$', unit=None, boundary=None),
#  'loge0': Uniform(minimum=44, maximum=54, name='loge0', latex_label='$\\log_{10}~E_{0}/{\\mathrm{erg}}$', unit=None, boundary=None),
#  'thc': Uniform(minimum=0.01, maximum=0.1, name='thc', latex_label='$\\theta_{\\mathrm{core}}~({\\mathrm{rad}})$', unit=None, boundary=None),
#  'logn0': Uniform(minimum=-5, maximum=2, name='logn0', latex_label='$\\log_{10}~n_{\\mathrm{ism}}/{\\mathrm{cm}}^{-3}$', unit=None, boundary=None),
#  'p': Uniform(minimum=2, maximum=3, name='p', latex_label='$p$', unit=None, boundary=None),
#  'logepse': Uniform(minimum=-5, maximum=0, name='logepse', latex_label='$\\log_{10}~\\epsilon_{e}$', unit=None, boundary=None),
# ...

# %%
#that_priors['loge0_const']= Constraint(minimum=49, maximum=53)
#that_priors['p_const']= Constraint(minimum=2.01, maximum=2.5)
#that_priors.update(redback.priors.get_priors(model='tophat'))
that_priors['p']=  2.3
that_priors['loge0']= Uniform(minimum=46, maximum=53, name='loge0', latex_label='$\\log_{10}E_{0}$', unit=None, boundary=None)
that_priors['redshift']= 0.01
that_priors['logepse']= -1.25
that_priors['logepsb']= -2.5
that_priors['xiN']= 1.0
that_priors['g0']= 1000
#that_priors['thv']=Sine(minimum=0, maximum=0.3, name='thv', latex_label='$\\theta_{\\mathrm{observer}}$', unit=None, boundary=None)
that_priors
# Out:
# {'redshift': 0.01,
#  'thv': Sine(minimum=0, maximum=1.5707963267948966, name='thv', latex_label='$\\theta_{\\mathrm{observer}}~(\\mathrm{rad})$', unit=None, boundary=None),
#  'loge0': Uniform(minimum=46, maximum=53, name='loge0', latex_label='$\\log_{10}E_{0}$', unit=None, boundary=None),
#  'thc': Uniform(minimum=0.01, maximum=0.1, name='thc', latex_label='$\\theta_{\\mathrm{core}}~({\\mathrm{rad}})$', unit=None, boundary=None),
#  'logn0': Uniform(minimum=-5, maximum=2, name='logn0', latex_label='$\\log_{10}~n_{\\mathrm{ism}}/{\\mathrm{cm}}^{-3}$', unit=None, boundary=None),
#  'p': 2.3,
#  'logepse': -1.25,
#  'logepsb': -2.5,
#  'xiN': 1.0,
#  'g0': 1000}

# %%
sample=that_priors.sample(10000)
tophat_data=pd.DataFrame.from_dict(sample)
tophat_data= tophat_data[tophat_data['thc'] < tophat_data['thv']]
#onaxis = tophat_data[tophat_data['thv'] < 0.05]
#offaxis= tophat_data[tophat_data['thv'] > 0.06]
tophat_data
# Out:
#       redshift       thv      loge0       thc     logn0    p  logepse  \
# 0         0.01  0.391528  49.571414  0.022444 -3.914258  2.3    -1.25
# 1         0.01  0.806277  50.206167  0.054905 -2.754684  2.3    -1.25
# 2         0.01  0.824264  52.104789  0.096556 -0.124633  2.3    -1.25
# 3         0.01  0.709184  51.657565  0.011765 -4.828502  2.3    -1.25
# 4         0.01  1.224696  51.780327  0.086995 -4.080894  2.3    -1.25
# ...        ...       ...        ...       ...       ...  ...      ...
# 9995      0.01  1.392940  48.318496  0.052521 -4.835067  2.3    -1.25
# 9996      0.01  1.165281  46.926523  0.084405 -2.206242  2.3    -1.25
# 9997      0.01  1.325038  50.475624  0.078557  1.421568  2.3    -1.25
# 9998      0.01  1.334321  48.358511  0.032618 -2.214813  2.3    -1.25
# 9999      0.01  1.496594  46.122687  0.056999  0.354799  2.3    -1.25
#
#       logepsb  ksin      g0
# 0        -2.5   1.0  1000.0
# 1        -2.5   1.0  1000.0
# 2        -2.5   1.0  1000.0
# ...

# %%
def tophat_peak(time, frequency, redshift, thv, loge0,thc,logn0,p,logepse,logepsb,ksin,g0):
   
    flux= redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, redshift=redshift, av=0.5,
        base_model='tophat',  thv= thv, loge0=loge0 , thc=thc, logn0=logn0, p=p, logepse=logepse, logepsb=logepsb, ksin=ksin, g0=g0,
        output_format='flux_density', frequency=frequency)
    
    return time[np.argmax(flux)], flux

# %%
time= np.linspace(0.01, 300,200)
indexoff=[] #indexes to keep for off axis
indexon=[] #indexes for on axis

for i in range(len(tophat_data)):
    
    parameters=np.array(tophat_data.iloc[i])
    peaktime, peakflux = tophat_peak(time, frequencies[7], *parameters)
    if max(peakflux)> 10e-12:
        if peaktime < 200 and peaktime >0.01:
            indexoff.append(i)
        elif peaktime == 0.01:
            indexon.append(i)
        
off_axis = tophat_data.iloc[indexoff]
on_axis = tophat_data.iloc[indexon]

# %% [markdown]
# peaktime may be more relevant for two layer rather than metzger/stratified so cannot refine data by peak too much- gives higher chance of seeing at lower peak times but not always necessary- min flux detectable?

# %%
off_axis
# Out:
#       redshift       thv      loge0       thc     logn0    p  logepse  \
# 0         0.01  0.258910  51.332448  0.050328 -4.878111  2.3    -1.25
# 3         0.01  0.263059  51.610792  0.017807 -2.515328  2.3    -1.25
# 6         0.01  0.290360  51.549303  0.084962 -4.315269  2.3    -1.25
# 10        0.01  0.263318  48.406981  0.076928 -0.961843  2.3    -1.25
# 11        0.01  0.232505  50.363534  0.065258  0.083106  2.3    -1.25
# ...        ...       ...        ...       ...       ...  ...      ...
# 9993      0.01  0.225026  52.020114  0.067156  0.252571  2.3    -1.25
# 9994      0.01  0.163709  50.183883  0.097577 -2.620262  2.3    -1.25
# 9995      0.01  0.160055  48.922202  0.038153 -0.108229  2.3    -1.25
# 9997      0.01  0.209502  48.728010  0.079531 -3.019317  2.3    -1.25
# 9999      0.01  0.172104  51.971352  0.068334  0.509182  2.3    -1.25
#
#       logepsb  ksin      g0
# 0        -2.5   1.0  1000.0
# 3        -2.5   1.0  1000.0
# 6        -2.5   1.0  1000.0
# ...

# %%
on_axis
# Out:
#       redshift       thv      loge0       thc     logn0    p  logepse  \
# 46        0.01  0.089198  46.107882  0.076245  1.152187  2.3    -1.25
# 64        0.01  0.182706  46.069596  0.088822  0.267702  2.3    -1.25
# 97        0.01  0.215524  47.428329  0.086182  1.444946  2.3    -1.25
# 149       0.01  0.100123  48.622159  0.099546 -0.383258  2.3    -1.25
# 254       0.01  0.064712  48.438706  0.038912 -3.683531  2.3    -1.25
# ...        ...       ...        ...       ...       ...  ...      ...
# 9248      0.01  0.336331  46.990778  0.061723  1.615567  2.3    -1.25
# 9340      0.01  0.065915  49.811231  0.064037 -1.337817  2.3    -1.25
# 9413      0.01  0.412785  46.294904  0.032532  1.769741  2.3    -1.25
# 9585      0.01  0.065937  49.171579  0.025586 -1.315726  2.3    -1.25
# 9947      0.01  0.099713  50.514747  0.074625  0.852627  2.3    -1.25
#
#       logepsb  ksin      g0
# 46       -2.5   1.0  1000.0
# 64       -2.5   1.0  1000.0
# 97       -2.5   1.0  1000.0
# ...

# %%
ax=plt.subplot()
ax.hist(off_axis['thv'], fill=None, edgecolor='r', label='refined data')
ax.hist(tophat_data['thv'], fill=None, label='original sample' )
ax.legend()
plt.show()

# %% [markdown]
# thv peak shifts higher for higher peak cutoff

# %%
ax1=plt.subplot
ax1.hist(off_axis['loge0'], fill=None, edgecolor='r', label='refined data')
ax.hist(tophat_data['loge0'], fill=None, label='original sample' )
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 2
#       1 ax1=plt.subplot
# ----> 2 ax1.hist(off_axis['loge0'], fill=None, edgecolor='r', label='refined data')
#       3 ax.hist(tophat_data['loge0'], fill=None, label='original sample' )
#       4 plt.legend()
#
# AttributeError: 'function' object has no attribute 'hist'

# %% [markdown]
# consistent trend suggests lower e0 more likely across diff cutoff times, setting minimum flux cuts off/decreases lower values

# %%
ax2=plt.subplot()
ax2.hist(off_axis['logn0'], fill=None, edgecolor='r', label='refined data', bins=50, histtype='step', density=True)
ax2.hist(tophat_data['logn0'], fill=None, label='original sample', histtype='step',bins=50, density=True )
plt.legend()
plt.show()

# %%
plt.hist(off_axis['logn0'])
plt.show()

# %% [markdown]
# consistent trend suggests higher logn0 more likely across diff cutoff times

# %%
data= np.array([off_axis['logn0'],off_axis['loge0'],off_axis['thv'],off_axis['thc']])
data=data.transpose()

newdata=that_priors.sample(10000)
newdata=pd.DataFrame.from_dict(newdata)
newdata=np.array([newdata['logn0'],newdata['loge0'],newdata['thv'],newdata['thc']])
newdata=newdata.transpose()
figure=corner.corner(data, labels=["logn0", "loge0", 'thv','thc'], quantiles=[0.16, 0.5, 0.84], show_titles=True, color='red')
figure=corner.corner(newdata, labels=["logn0", "loge0", 'thv','thc'], quantiles=[0.16, 0.5, 0.84], show_titles=True, color='blue', fig=figure)
figure

# %%
0.31, 49.74,0.87,0.06
# Out:
# (0.31, 49.74, 0.87, 0.06)

# %%
plt.hist(on_axis['thv'], fill=None, edgecolor='r', label='refined data')
plt.hist(tophat_data['thv'], fill=None, label='original sample' )
plt.xlim(0,0.5)
#plt.ylim(0,200)
plt.legend()

# %%
plt.hist(on_axis['loge0'], fill=None, edgecolor='r', label='refined data')
plt.hist(tophat_data['loge0'], fill=None, label='original sample' )
#plt.ylim(0,100)
plt.legend()

# %%
plt.hist(on_axis['logn0'], fill=None, edgecolor='r', label='refined data')
plt.hist(tophat_data['logn0'], fill=None, label='original sample' )
#plt.ylim(0,100)
plt.legend()

# %%
data= np.array([on_axis['logn0'],on_axis['loge0'],on_axis['thv'],on_axis['thc']])
data=data.transpose()

figure=corner.corner(data, labels=["logn0", "loge0", 'thv','thc'], quantiles=[0.16, 0.5, 0.84], show_titles=True)
figure

# %%
0.53,47.69,0.14,0.06

# %%
strat_priors = redback.priors.get_priors(model='two_layer_stratified_kilonova')
#that_priors = redback.priors.get_priors(model='tophat')
strat_priors['redshift']=0.01
strat_priors
# Out:
# {'redshift': 0.01,
#  'mej': Uniform(minimum=0.01, maximum=0.05, name='mej', latex_label='$M_{\\mathrm{ej}}[M_{\\odot}]$', unit=None, boundary=None),
#  'vej_1': Uniform(minimum=0.05, maximum=0.2, name='vej_1', latex_label='$v_{\\mathrm{ej}-1}[c]$', unit=None, boundary=None),
#  'vej_2': Uniform(minimum=0.3, maximum=0.5, name='vej_2', latex_label='$v_{\\mathrm{ej}-2}[c]$', unit=None, boundary=None),
#  'kappa': Uniform(minimum=1, maximum=30, name='kappa', latex_label='$\\kappa$', unit=None, boundary=None),
#  'beta': Uniform(minimum=1.5, maximum=8, name='beta', latex_label='$\\beta$', unit=None, boundary=None)}

# %%
sample=strat_priors.sample(10000)
stratified_data=pd.DataFrame.from_dict(sample)
#stratified_data= stratified_data[stratified_data['vej1'] < stratified_data['vej2']]

# %%
def stratified_peak(time, frequency, redshift, mej, vej_1,vej_2,kappa,beta):
   
    flux= redback.transient_models.extinction_models.extinction_with_kilonova_base_model(time=time, redshift=redshift, av=0.5,
        base_model='two_layer_stratified_kilonova', mej=mej, vej_1=vej_1, vej_2=vej_2, kappa=kappa, beta=beta,
        output_format='flux_density', frequency=frequency)
    
    return time[np.argmax(flux)], flux

# %%
time= np.linspace(0.03,30,50)
index=[]

for i in range(len(stratified_data)):
    
    parameters=np.array(stratified_data.iloc[i])
    peaktime, peakflux = stratified_peak(time, frequencies[7], *parameters)
    if max(peakflux)> 10e-10:
        if peaktime < 20:
            index.append(i)
            
stratified_data= stratified_data.iloc[index] 
stratified_data
# Out:
#       redshift       mej     vej_1     vej_2      kappa      beta
# 0         0.01  0.014538  0.106013  0.485057  24.401387  7.532413
# 1         0.01  0.015544  0.066612  0.339011  24.452447  2.612570
# 2         0.01  0.043932  0.143253  0.333960  14.759564  6.701042
# 3         0.01  0.023482  0.144102  0.450282  15.946773  2.229125
# 4         0.01  0.020135  0.108739  0.417402   4.782055  7.897904
# ...        ...       ...       ...       ...        ...       ...
# 9995      0.01  0.024183  0.084781  0.361508  21.628842  7.083160
# 9996      0.01  0.023814  0.196014  0.478973  22.778632  6.272362
# 9997      0.01  0.046232  0.056128  0.416848  25.612894  3.987298
# 9998      0.01  0.025939  0.121259  0.306300  23.731060  3.203690
# 9999      0.01  0.044619  0.191604  0.339945  16.271553  3.929124
#
# [9529 rows x 6 columns]

# %%
data= np.array([stratified_data['mej'],stratified_data['vej_1'],stratified_data['vej_2'],stratified_data['kappa'], stratified_data['beta']])
data=data.transpose()

figure=corner.corner(data, labels=["mej", "vej_1", 'vej_2','kappa','beta'], quantiles=[0.16, 0.5, 0.84], show_titles=True)

# %%
time= np.linspace(0.03,30,50)
for i in range(100):
        flux= redback.transient_models.extinction_models.extinction_with_kilonova_base_model(time=time, av=0.5,
          base_model='two_layer_stratified_kilonova', 
          output_format='flux_density', frequency=frequencies[1],**stratified_data.iloc[i])
        plt.loglog(time,flux)
        plt.ylim(10e-20,10)
        
print(np.interp(1,time,flux))
# Out:
# 0.05378245827877729

# %%
time= np.linspace(0.03,100,100)
for i in range(100):
        flux= redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, av=0.5,
          base_model='tophat', 
          output_format='flux_density', frequency=frequencies[4],**tophat_data.iloc[i])
        plt.loglog(time,flux)
        plt.ylim(10e-20,10)

# %%
def afterglow_constraints(parameters):
    constrained_params= parameters.copy()
    print(constrained_params)
    time=np.linspace(0.1,100,100) #make sure time arrays match
    maxflux=[]
    peaktime=[]
    minflux=[]
    if isinstance(parameters['thv'], (float,int)):
        size= 1
    else:
        size=len(parameters['thv'])
    print(size)
    for i in range(len(parameters['thv'])):
        flux= redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, redshift=0.01, av=0.5,
            base_model='tophat_redback',  thv= parameters['thv'][i], loge0=parameters['loge0'][i] , thc=parameters['thc'][i], logn0=parameters['logn0'][i], 
            p=2.3, logepse=-1.25, logepsb=-2.5, xiN=1.0, g0=1000,
            output_format='flux_density', frequency=frequencies[4])
        maxflux.append(max(flux))
        peaktime.append(time[np.argmax(flux)])
        fluxday1= np.interp(1,time,flux)
        minflux.append(fluxday1)
        
    #peak flux must be at times < 200 days
    constrained_params['peak_time']= 200 - np.array(peaktime)
    #peak flux must be greater than 10e-12
    constrained_params['max_flux']= np.array(maxflux) - (10e-12)
    #thv-thc for off axis, thc-thv for on axis
    constrained_params['alignment']= parameters['thc'] - parameters['thv']
    #filter lower flux afterglows out for ON AXIS case (comment out if needed)
    constrained_params['min_flux']= np.array(minflux) - 10e-7
    
    return constrained_params

# %%
priors = PriorDict(conversion_function=afterglow_constraints)
priors['max_flux']= Constraint(minimum=0, maximum=20)
priors['peak_time']= Constraint(minimum=0, maximum=250)
priors['alignment']= Constraint(minimum=0, maximum=1.57)
priors['min_flux']=Constraint(minimum=0, maximum=10)
priors.update(redback.priors.get_priors(model='tophat_redback'))
priors['p']=  2.3
priors['loge0']= Uniform(minimum=46, maximum=53, name='loge0', latex_label='$\\log_{10}E_{0}$', unit=None, boundary=None)
priors['thv']= Uniform(minimum=0, maximum=0.1, name='thv', latex_label='thv', unit=None, boundary=None)
priors['redshift']= 0.01
priors['logepse']= -1.25
priors['logepsb']= -2.5
priors['xiN']= 1.0
priors['g0']= 1000
priors
#samples=priors.sample(2)

#afterglow_data=pd.DataFrame.from_dict(samples)
# Out:
# {'max_flux': Constraint(minimum=0, maximum=20, name=None, latex_label=None, unit=None),
#  'peak_time': Constraint(minimum=0, maximum=250, name=None, latex_label=None, unit=None),
#  'alignment': Constraint(minimum=0, maximum=1.57, name=None, latex_label=None, unit=None),
#  'min_flux': Constraint(minimum=0, maximum=10, name=None, latex_label=None, unit=None),
#  'redshift': 0.01,
#  'thv': Uniform(minimum=0, maximum=0.1, name='thv', latex_label='thv', unit=None, boundary=None),
#  'loge0': Uniform(minimum=46, maximum=53, name='loge0', latex_label='$\\log_{10}E_{0}$', unit=None, boundary=None),
#  'thc': Uniform(minimum=0.01, maximum=0.1, name='thc', latex_label='$\\theta_{\\mathrm{core}}~({\\mathrm{rad}})$', unit=None, boundary=None),
#  'logn0': Uniform(minimum=-5, maximum=2, name='logn0', latex_label='$\\log_{10}~n_{\\mathrm{ism}}/{\\mathrm{cm}}^{-3}$', unit=None, boundary=None),
#  'p': 2.3,
#  'logepse': -1.25,
#  'logepsb': -2.5,
#  'xiN': 1.0,
#  'g0': 1000}

# %%
samples=priors.sample(4)
samples
# Out:
# {'redshift': array([0.01, 0.01, 0.01, 0.01]), 'thv': array([0.05225862, 0.00395894, 0.04014835, 0.03640156]), 'loge0': array([52.31577853, 50.96025513, 48.1898717 , 51.01370691]), 'thc': array([0.03770094, 0.01700925, 0.02687546, 0.05975631]), 'logn0': array([-2.60562608,  0.64751207, -4.87930747, -0.14230156]), 'p': array([2.3, 2.3, 2.3, 2.3]), 'logepse': array([-1.25, -1.25, -1.25, -1.25]), 'logepsb': array([-2.5, -2.5, -2.5, -2.5]), 'xiN': array([1., 1., 1., 1.]), 'g0': array([1000., 1000., 1000., 1000.])}
# 4
# ...

# %%
afterglow_data=pd.DataFrame.from_dict(samples)

time=np.linspace(0.1,100,100)
for i in range(50):
    flux= redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, av=0.5,
            base_model='tophat_redback',  **afterglow_data.iloc[i],
            output_format='flux_density', frequency=frequencies[4])
    print(np.interp(1,time,flux))

# %%
afterglow_data.to_csv("onaxis_samples_redback.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 afterglow_data.to_csv("onaxis_samples_redback.csv")
#
# NameError: name 'afterglow_data' is not defined

# %%
afterglow_data= pd.read_csv('onaxis_samples_redback.csv')

# %%
priordata=that_priors.sample(5000)
priordata=pd.DataFrame.from_dict(priordata)

# %%
fig,ax=plt.subplots(ncols=2, nrows=2, figsize=(8,8))
ax[0,0].hist(afterglow_data['logn0'], fill=None, edgecolor='r', label='constrained', bins=50, histtype='step', density=True)
ax[0,0].hist(priordata['logn0'], fill=None, edgecolor='b', label='original', histtype='step',bins=50, density=True )
ax[0,0].set_xlabel('logn0')
ax[0,0].axvline(x=np.percentile(afterglow_data['logn0'],16), ls='--', c='r')
ax[0,0].axvline(x=np.percentile(afterglow_data['logn0'],50), ls='--', c='r')
ax[0,0].axvline(x=np.percentile(afterglow_data['logn0'],84), ls='--', c='r')
ax[0,0].axvline(x=np.percentile(priordata['logn0'],16), ls='--', c='b')
ax[0,0].axvline(x=np.percentile(priordata['logn0'],50), ls='--', c='b')
ax[0,0].axvline(x=np.percentile(priordata['logn0'],84), ls='--', c='b')

ax[0,1].hist(afterglow_data['loge0'], fill=None, edgecolor='r', label='constrained', bins=50, histtype='step', density=True)
ax[0,1].hist(priordata['loge0'], edgecolor='b', fill=None, label='original', histtype='step',bins=50, density=True )
ax[0,1].set_xlabel('loge0')
ax[0,1].axvline(x=np.percentile(afterglow_data['loge0'],16), ls='--', c='r')
ax[0,1].axvline(x=np.percentile(afterglow_data['loge0'],50), ls='--', c='r')
ax[0,1].axvline(x=np.percentile(afterglow_data['loge0'],84), ls='--', c='r')
ax[0,1].axvline(x=np.percentile(priordata['loge0'],16), ls='--', c='b')
ax[0,1].axvline(x=np.percentile(priordata['loge0'],50), ls='--', c='b')
ax[0,1].axvline(x=np.percentile(priordata['loge0'],84), ls='--', c='b')

ax[1,0].hist(afterglow_data['thv'], fill=None, edgecolor='r', label='constrained', bins=50, histtype='step', density=True)
ax[1,0].hist(priordata['thv'], fill=None, edgecolor='b', label='original', histtype='step',bins=50, density=True )
ax[1,0].set_xlabel('thv')
ax[1,0].axvline(x=np.percentile(afterglow_data['thv'],16), ls='--', c='r')
ax[1,0].axvline(x=np.percentile(afterglow_data['thv'],50), ls='--', c='r')
ax[1,0].axvline(x=np.percentile(afterglow_data['thv'],84), ls='--', c='r')
ax[1,0].axvline(x=np.percentile(priordata['thv'],16), ls='--', c='b')
ax[1,0].axvline(x=np.percentile(priordata['thv'],50), ls='--', c='b')
ax[1,0].axvline(x=np.percentile(priordata['thv'],84), ls='--', c='b')
ax[1,0].legend()

ax[1,1].hist(afterglow_data['thc'], fill=None, edgecolor='r', label='constrained', bins=50, histtype='step', density=True)
ax[1,1].hist(priordata['thc'], fill=None, edgecolor='b', label='original', histtype='step',bins=50, density=True )
ax[1,1].set_xlabel('thc')
ax[1,1].axvline(x=np.percentile(afterglow_data['thc'],16), ls='--', c='r')
ax[1,1].axvline(x=np.percentile(afterglow_data['thc'],50), ls='--', c='r')
ax[1,1].axvline(x=np.percentile(afterglow_data['thc'],84), ls='--', c='r')
ax[1,1].axvline(x=np.percentile(priordata['thc'],16), ls='--', c='b')
ax[1,1].axvline(x=np.percentile(priordata['thc'],50), ls='--', c='b')
ax[1,1].axvline(x=np.percentile(priordata['thc'],84), ls='--', c='b')

plt.savefig('onax_histograms.png', dpi='figure')
plt.show()

# %%
ax=plt.subplot()
ax.hist(afterglow_data['loge0'], fill=None, edgecolor='r', label='constrained', bins=50, histtype='step', density=True)
ax.hist(priordata['loge0'], edgecolor='b', fill=None, label='original', histtype='step',bins=50, density=True )
plt.legend(loc='upper left')
ax.set_xlabel('loge0')
plt.axvline(x=np.percentile(afterglow_data['loge0'],16), ls='--', c='r')
plt.axvline(x=np.percentile(afterglow_data['loge0'],50), ls='--', c='r')
plt.axvline(x=np.percentile(afterglow_data['loge0'],84), ls='--', c='r')
plt.axvline(x=np.percentile(priordata['loge0'],16), ls='--', c='b')
plt.axvline(x=np.percentile(priordata['loge0'],50), ls='--', c='b')
plt.axvline(x=np.percentile(priordata['loge0'],84), ls='--', c='b')
plt.savefig('offax_loge0.png', dpi='figure')
plt.show()

# %%
ax=plt.subplot()
ax.hist(afterglow_data['thc'], fill=None, edgecolor='r', label='constrained', bins=50, histtype='step', density=True)
ax.hist(priordata['thc'], fill=None, edgecolor='b', label='original', histtype='step',bins=50, density=True )
plt.legend(loc='lower left')
ax.set_xlabel('thc')
plt.axvline(x=np.percentile(afterglow_data['thc'],16), ls='--', c='r')
plt.axvline(x=np.percentile(afterglow_data['thc'],50), ls='--', c='r')
plt.axvline(x=np.percentile(afterglow_data['thc'],84), ls='--', c='r')
plt.axvline(x=np.percentile(priordata['thc'],16), ls='--', c='b')
plt.axvline(x=np.percentile(priordata['thc'],50), ls='--', c='b')
plt.axvline(x=np.percentile(priordata['thc'],84), ls='--', c='b')
plt.savefig('offax_thc.png', dpi='figure')
plt.show()

# %%
ax=plt.subplot()
ax.hist(afterglow_data['thv'], fill=None, edgecolor='r', label='refined data', bins=50, histtype='step', density=True)
ax.hist(priordata['thv'], fill=None, label='original sample', histtype='step',bins=50, density=True )
plt.legend()
plt.show()

# %%
on_axisdata= pd.read_csv('onaxis_samples_redback.csv')
on_axisdata
# Out:
#       Unnamed: 0  redshift       thv      loge0       thc     logn0    p  \
# 0              0      0.01  0.685842  48.797762  0.028329 -1.384974  2.3
# 1              1      0.01  0.448122  50.602607  0.019581 -1.035629  2.3
# 2              2      0.01  1.206436  52.001955  0.055515  0.971383  2.3
# 3              3      0.01  0.367668  49.296070  0.093415  1.573206  2.3
# 4              4      0.01  1.217062  49.865790  0.092428 -2.965503  2.3
# ...          ...       ...       ...        ...       ...       ...  ...
# 4995        4995      0.01  1.524258  49.336186  0.021041  1.082228  2.3
# 4996        4996      0.01  0.946271  51.751605  0.088582 -1.598246  2.3
# 4997        4997      0.01  1.265183  47.587424  0.060532 -0.798082  2.3
# 4998        4998      0.01  1.438868  46.647065  0.077196  1.323297  2.3
# 4999        4999      0.01  0.913154  46.176370  0.094023 -0.421863  2.3
#
#       logepse  logepsb  xiN      g0
# 0       -1.25     -2.5  1.0  1000.0
# ...

# %%
agdata= np.array([on_axisdata['logn0'],on_axisdata['loge0'],on_axisdata['thv'],on_axisdata['thc']])
agdata= agdata.transpose()

original=np.array([priordata['logn0'],priordata['loge0'],priordata['thv'],priordata['thc']])
original=original.transpose()

figure=corner.corner(agdata, labels=["logn0", "loge0", 'thv','thc'], quantiles=[0.16, 0.5, 0.84], show_titles=True, color='red')
figure=corner.corner(original, labels=["logn0", "loge0", 'thv','thc'], quantiles=[0.16, 0.5, 0.84], color='blue', fig=figure)
plt.savefig("onaxis_corner_redback.png", dpi='figure')
