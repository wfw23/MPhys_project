# %%
import redback
import numpy as np
import pandas as pd
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
# Out:
# No module named 'lalsimulation'
# lalsimulation is not installed. Some EOS based models will not work. Please use bilby eos or pass your own EOS generation class to the model

# %%
bands = ['lsstg', 'lsstr', 'lssti','lsstz','lssty', 'lsstu', 'uvot::uvw1'] #u, v, uwot
frequency=[5e9, 2e15]
bandfreqs = (redback.utils.bands_to_frequency(bands))
frequency.extend(bandfreqs)
frequency.sort()
frequency
# Out:
# [5000000000.0,
#  308738116672272.25,
#  344949774531146.6,
#  397287890568202.3,
#  481730482385753.06,
#  621093082892117.8,
#  816711949886849.0,
#  1146839759677006.2,
#  2000000000000000.0]

# %%
#tophat jet and two component kilonova
time= np.linspace(0.01,30,50)
colour=['magenta','r', 'orange', 'y', 'g', 'c', 'b', 'purple', 'k']
ax= plt.subplot()

for i in range(9):
    
    kn_fluxd = redback.transient_models.extinction_models.extinction_with_kilonova_base_model(time=time, redshift=0.01, av=1,
        base_model='two_component_kilonova_model', mej_1=0.015, mej_2=0.015, vej_1=0.1, vej_2=0.2, kappa_1=4, kappa_2=25, 
        temperature_floor_1=3000, temperature_floor_2=3000, output_format='flux_density', frequency=frequency[i] )


    ag_fluxd = redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, redshift=0.01, av=1,
        base_model='tophat',  thv= 0.25, loge0=52.5 , thc= 0.03, logn0=-1, p=3, logepse=-1.5, logepsb=-1.5, ksin=0.4, g0=1000,
        output_format='flux_density', frequency=frequency[i])

    combined= ag_fluxd + kn_fluxd
    
    ax.semilogy(time, kn_fluxd, ls='dashed', color=colour[i])
    ax.semilogy(time, ag_fluxd, ls='dotted', color=colour[i])
    ax.semilogy(time, combined, ls= 'solid', color=colour[i], alpha=0.5)

#legend formatting
f1 = mpatches.Patch(color='magenta', label='5e9 Hz')
f2 = mpatches.Patch(color='r', label='308738116672272.25 Hz')
f3 = mpatches.Patch(color='orange', label='344949774531146.6 Hz')
f4 = mpatches.Patch(color='y', label='397287890568202.3 Hz')
f5 = mpatches.Patch(color='g', label='481730482385753.06 Hz')
f6 = mpatches.Patch(color='c', label='621093082892117.8 Hz')
f7 = mpatches.Patch(color='b', label='816711949886849.0 Hz')
f8 = mpatches.Patch(color='purple', label='1146839759677006.2 Hz')
f9 = mpatches.Patch(color='k', label='2e16 Hz')
kn = Line2D([0],[0],color='grey', ls='dashed', label='kilonova')
ag = Line2D([0],[0],color='grey', ls='dotted',label='afterglow')
both = Line2D([0],[0],color='grey',ls='solid', label='both')

ax.legend(handles=[f1,f2,f3,f4,f5,f6,f7,f8,f9,kn,ag,both],loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel('Time (days)')
ax.set_ylabel('Flux Density (mJy)')
plt.ylim(1e-15,1e0)
# Out:
# (1e-15, 1.0)

# %%
#powerlawcore jet and two component kn
time= np.linspace(0.01,30,50)
colour=['magenta','r', 'orange', 'y', 'g', 'c', 'b', 'purple', 'k']
ax= plt.subplot()

for i in range(9):
    
    kn_fluxd = redback.transient_models.extinction_models.extinction_with_kilonova_base_model(time=time, redshift=0.01, av=0.5,
        base_model='two_component_kilonova_model', mej_1=0.01, mej_2=0.018, vej_1=0.2, vej_2=0.1, kappa_1=5, kappa_2=25, 
        temperature_floor_1=3000, temperature_floor_2=3000, output_format='flux_density', frequency=frequency[i] )


    ag_fluxd = redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, redshift=0.01, av=0.5,
        base_model='powerlawcore',  thv= 0.2, loge0=52.5 , thc= 0.03, logn0=-2, p=3, logepse=-1.5, logepsb=-1.5, ksin=0.4, g0=1000, thw=5,
        beta= 4, output_format='flux_density', frequency=frequency[i])

    combined= ag_fluxd + kn_fluxd
    
    ax.semilogy(time, kn_fluxd, ls='dashed', color=colour[i])
    ax.semilogy(time, ag_fluxd, ls='dotted', color=colour[i])
    ax.semilogy(time, combined, ls= 'solid', color=colour[i], alpha=0.7)

#legend formatting
f1 = mpatches.Patch(color='magenta', label='5e9 Hz')
f2 = mpatches.Patch(color='r', label='308738116672272.25 Hz')
f3 = mpatches.Patch(color='orange', label='344949774531146.6 Hz')
f4 = mpatches.Patch(color='y', label='397287890568202.3 Hz')
f5 = mpatches.Patch(color='g', label='481730482385753.06 Hz')
f6 = mpatches.Patch(color='c', label='621093082892117.8 Hz')
f7 = mpatches.Patch(color='b', label='816711949886849.0 Hz')
f8 = mpatches.Patch(color='purple', label='1146839759677006.2 Hz')
f9 = mpatches.Patch(color='k', label='2e16 Hz')
kn = Line2D([0],[0],color='grey', ls='dashed', label='kilonova')
ag = Line2D([0],[0],color='grey', ls='dotted',label='afterglow')
both = Line2D([0],[0],color='grey',ls='solid', label='both')

ax.legend(handles=[f1,f2,f3,f4,f5,f6,f7,f8,f9,kn,ag,both],loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel('Time (days)')
ax.set_ylabel('Flux Density (mJy)')
#plt.ylim(1e-5,1e2)   
#plt.xlim(0,5)
# Out:
# Text(0, 0.5, 'Flux Density (mJy)')

# %%
#gaussian core jet and two component kn
time= np.linspace(0.01,30,50)
colour=['magenta','r', 'orange', 'y', 'g', 'c', 'b', 'purple', 'k']
ax= plt.subplot()

for i in range(9):
    
    kn_fluxd = redback.transient_models.extinction_models.extinction_with_kilonova_base_model(time=time, redshift=0.01, av=0.5,
        base_model='two_component_kilonova_model', mej_1=0.01, mej_2=0.018, vej_1=0.2, vej_2=0.1, kappa_1=1, kappa_2=30, 
        temperature_floor_1=3000, temperature_floor_2=3000, output_format='flux_density', frequency=frequency[i] )


    ag_fluxd = redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, redshift=0.01, av=0.5,
        base_model='gaussiancore',  thv= 0.25, loge0=52.5 , thc= 0.03, logn0=-2, p=3, logepse=-1.5, logepsb=-1.5, ksin=0.4, g0=1000, thw=5,
        beta= 4, output_format='flux_density', frequency=frequency[i])

    combined= ag_fluxd + kn_fluxd
    
    ax.semilogy(time, kn_fluxd, ls='dashed', color=colour[i])
    ax.semilogy(time, ag_fluxd, ls='dotted', color=colour[i])
    ax.semilogy(time, combined, ls= 'solid', color=colour[i], alpha=0.7)

#legend formatting
f1 = mpatches.Patch(color='magenta', label='5e9 Hz')
f2 = mpatches.Patch(color='r', label='308738116672272.25 Hz')
f3 = mpatches.Patch(color='orange', label='344949774531146.6 Hz')
f4 = mpatches.Patch(color='y', label='397287890568202.3 Hz')
f5 = mpatches.Patch(color='g', label='481730482385753.06 Hz')
f6 = mpatches.Patch(color='c', label='621093082892117.8 Hz')
f7 = mpatches.Patch(color='b', label='816711949886849.0 Hz')
f8 = mpatches.Patch(color='purple', label='1146839759677006.2 Hz')
f9 = mpatches.Patch(color='k', label='2e16 Hz')
kn = Line2D([0],[0],color='grey', ls='dashed', label='kilonova')
ag = Line2D([0],[0],color='grey', ls='dotted',label='afterglow')
both = Line2D([0],[0],color='grey',ls='solid', label='both')

ax.legend(handles=[f1,f2,f3,f4,f5,f6,f7,f8,f9,kn,ag,both],loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel('Time (days)')
ax.set_ylabel('Flux Density (mJy)')
#plt.ylim(1e-5,1e2)   
#plt.xlim(0,5)
# Out:
# Text(0, 0.5, 'Flux Density (mJy)')

# %%
#powerlawcore jet and stratified kn
time= np.linspace(0.03,30,50)
colour=['magenta','r', 'orange', 'y', 'g', 'c', 'b', 'purple', 'k']
ax= plt.subplot()

for i in range(9):
    
    kn_fluxd = redback.transient_models.extinction_models.extinction_with_kilonova_base_model(time=time, redshift=0.01, av=0.5,
        base_model='two_layer_stratified_kilonova', mej=0.03, vej_1=0.1, vej_2=0.4, kappa=3, beta=4, 
        output_format='flux_density', frequency=frequency[i] )


    ag_fluxd = redback.transient_models.extinction_models.extinction_with_afterglow_base_model(time=time, redshift=0.01, av=0.5,
        base_model='powerlawcore',  thv= 0.2, loge0=52.5 , thc= 0.03, logn0=-2, p=4, logepse=-1.5, logepsb=-1.5, ksin=0.4, g0=1000, thw=5,
        beta= 4, output_format='flux_density', frequency=frequency[i])

    combined= ag_fluxd + kn_fluxd
    
    ax.semilogy(time, kn_fluxd, ls='dashed', color=colour[i])
    ax.semilogy(time, ag_fluxd, ls='dotted', color=colour[i])
    ax.semilogy(time, combined, ls= 'solid', color=colour[i], alpha=0.7)

#legend formatting
f1 = mpatches.Patch(color='magenta', label='5e9 Hz')
f2 = mpatches.Patch(color='r', label='308738116672272.25 Hz')
f3 = mpatches.Patch(color='orange', label='344949774531146.6 Hz')
f4 = mpatches.Patch(color='y', label='397287890568202.3 Hz')
f5 = mpatches.Patch(color='g', label='481730482385753.06 Hz')
f6 = mpatches.Patch(color='c', label='621093082892117.8 Hz')
f7 = mpatches.Patch(color='b', label='816711949886849.0 Hz')
f8 = mpatches.Patch(color='purple', label='1146839759677006.2 Hz')
f9 = mpatches.Patch(color='k', label='2e16 Hz')
kn = Line2D([0],[0],color='grey', ls='dashed', label='kilonova')
ag = Line2D([0],[0],color='grey', ls='dotted',label='afterglow')
both = Line2D([0],[0],color='grey',ls='solid', label='both')

ax.legend(handles=[f1,f2,f3,f4,f5,f6,f7,f8,f9,kn,ag,both],loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_xlabel('Time (days)')
ax.set_ylabel('Flux Density (mJy)')
plt.ylim(1e-12,1e2)   
#plt.xlim(0,5)
# Out:
# (1e-12, 100.0)
